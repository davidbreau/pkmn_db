# %%
import os, pandas as pd, sys

# %%
current_dir = os.path.abspath('')
parent_dir = os.path.dirname(os.path.dirname(current_dir))
sys.path.append(parent_dir)

# Maintenant, essayez d'importer la classe Database
from B___Data.test_connector import Database

# %%
from A___Database_Building.A3__Crud.create import create_pkmn
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from A___Database_Building.A3__Crud.create import create_pkmn
#
# ImportError: cannot import name 'create_pkmn' from 'A___Database_Building.A3__Crud.create' (/home/utilisateur/Projets/pkmn_db/A___Database_Building/A3__Crud/create.py)
