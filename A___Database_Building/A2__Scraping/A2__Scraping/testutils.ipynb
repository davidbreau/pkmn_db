# %%
import sqlite3, pandas as pd

# %%
df = pd.read_csv('../../../B___Data/CSV/pokemons.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1151 entries, 0 to 1150
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   nom_pkmn          1151 non-null   object
#  1   nom_pkmn_us       1151 non-null   object
#  2   num_pokedex       1151 non-null   int64
#  3   url_image         1151 non-null   object
#  4   type_1            1151 non-null   object
#  5   type_2            620 non-null    object
#  6   taille_m          1146 non-null   object
#  7   poids_kg          1151 non-null   object
#  8   talent_1          1127 non-null   object
#  9   talent_2          568 non-null    object
#  10  talent_cache      899 non-null    object
#  11  sexe              1151 non-null   object
#  12  taux_de_capture   1036 non-null   float64
#  13  cycle_eclosion    1037 non-null   float64
#  14  groupe_oeuf_1     1037 non-null   object
#  15  groupe_oeuf_2     286 non-null    object
#  16  points_effort     1035 non-null   object
#  17  points_exp        1037 non-null   object
#  18  exp_niv100        1037 non-null   object
#  19  pv                1117 non-null   float64
#  20  attaque           1115 non-null   float64
#  21  attaque_speciale  1115 non-null   float64
#  22  defense           1115 non-null   float64
#  23  defense_speciale  1119 non-null   float64
#  24  vitesse           1119 non-null   float64
# dtypes: float64(8), int64(1), object(16)
# memory usage: 224.9+ KB

# %%
df[df.talent_1.isna()].sort_values(by='num_pokedex')
# Out:
#               nom_pkmn            nom_pkmn_us  num_pokedex  \
# 1073           Caninos              Growlithe           58
# 1051        Gravalanch               Graveler           75
# 803          Tengalice                Shiftry          275
# 666            Tiplouf                 Piplup          393
# 665          Prinplouf               Prinplup          394
# 664          Pingoléon               Empoleon          395
# 545          Nodulithe             Roggenrola          524
# 523          Brutapode              Scolipede          545
# 517          Bargantua               Basculin          550
# 452          Lugulabre             Chandelure          609
# 420             Boréas               Tornadus          641
# 419           Fulguris              Thundurus          642
# 416          Démétéros               Landorus          645
# 401          Amphinobi               Greninja          658
# 381          Mistigrix               Meowstic          678
# 322            Rocabot               Rockruff          744
# 321           Lougaroc               Lycanroc          745
# 208   Salarsen Gigamax  Gigantamax Toxtricity          849
# 209           Salarsen             Toxtricity          849
# 181           Wimessir               Indeedee          876
# 151           Amovénus               Enamorus          905
# 144           Fragroin             Oinkologne          916
# 130           Tapatoès           Squawkabilly          931
# 53             Ogerpon                Ogerpon         1017
#
#                                               url_image    type_1    type_2  \
# 1073  /images/thumb/e/e2/Caninos-RFVF.png/250px-Cani...       Feu       NaN
# 1051  /images/thumb/a/a5/Gravalanch-RFVF.png/250px-G...     Roche       Sol
# 803   /images/thumb/d/d2/Tengalice-RS.png/250px-Teng...    Plante  Ténèbres
# 666   /images/thumb/c/c2/Tiplouf-DEPS.png/250px-Tipl...       Eau       NaN
# 665   /images/thumb/c/c5/Prinplouf-DEPS.png/250px-Pr...       Eau       NaN
# 664   /images/thumb/1/14/Pingol%C3%A9on-DEPS.png/250...       Eau     Acier
# 545   /images/thumb/2/2d/Nodulithe-NB.png/250px-Nodu...     Roche       NaN
# 523   /images/thumb/f/f1/Brutapode-NB.png/250px-Brut...   Insecte    Poison
# 517   /images/thumb/f/fa/Bargantua_%28Motif_Blanc%29...       Eau       NaN
# 452   /images/thumb/d/d2/Lugulabre-NB.png/250px-Lugu...   Spectre       Feu
# 420   /images/thumb/1/1b/Bor%C3%A9as_%28Forme_Avatar...       Vol       NaN
# 419   /images/thumb/1/1b/Fulguris_%28Forme_Avatar%29...  Électrik       Vol
# 416   /images/thumb/8/87/D%C3%A9m%C3%A9t%C3%A9ros_%2...       Sol       Vol
# 401   /images/thumb/7/75/Amphinobi-XY.png/250px-Amph...       Eau  Ténèbres
# 381   /images/thumb/5/57/Mistigrix_%28Femelle%29-XY....       Psy       NaN
# 322   /images/thumb/b/b0/Rocabot-SL.png/250px-Rocabo...     Roche       NaN
# 321   /images/thumb/6/63/Lougaroc_%28Forme_Diurne%29...     Roche       NaN
# 208   /images/thumb/1/16/Salarsen_%28Gigamax%29-EB.p...  Électrik    Poison
# 209   /images/thumb/a/ad/Salarsen_%28Forme_Aig%C3%BC...  Électrik    Poison
# 181   /images/thumb/5/5b/Wimessir_%28M%C3%A2le%29-EB...       Psy    Normal
# 151   /images/thumb/9/9f/Amov%C3%A9nus_%28Forme_Avat...       Fée       Vol
# 144   /images/thumb/a/a0/Fragroin_%28Femelle%29-EV.p...    Normal       NaN
# 130   /images/thumb/b/b1/Tapato%C3%A8s_%28Plumage_Ve...    Normal       Vol
# 53    /images/thumb/8/82/Ogerpon_%28Masque_Turquoise...    Bipède       NaN
#
#      taille_m poids_kg talent_1 talent_2  ... groupe_oeuf_2 points_effort  \
# 1073      0,7     19,0      NaN      NaN  ...           NaN        +1 Att
# 1051      1,0    105,0      NaN      NaN  ...           NaN       +2 Déf.
# 803       1,3     59,6      NaN      NaN  ...       Végétal       +3 Att.
# 666       0,4      5,2      NaN      NaN  ...     Terrestre   +1 Att. Spé
# 665       0,8     23,0      NaN      NaN  ...     Terrestre   +2 Att. Spé
# 664       1,7     84,5      NaN      NaN  ...     Terrestre   +3 Att. Spé
# 545       0,4     18,0      NaN      NaN  ...           NaN       +1 Déf.
# 523       2,5    200,5      NaN      NaN  ...           NaN       +3 Vit.
# 517       1,0     18,0      NaN      NaN  ...           NaN       +2 Vit.
# 452       1,0     34,3      NaN      NaN  ...           NaN   +3 Att. Spé
# 420       NaN     63,0      NaN      NaN  ...           NaN   +3 Att. Spé
# 419       NaN     61,0      NaN      NaN  ...           NaN   +3 Att. Spé
# 416       NaN     68,0      NaN      NaN  ...           NaN       +3 Att.
# 401       1,5     40,0      NaN      NaN  ...           NaN    +3 Vitesse
# 381       0,6      8,5      NaN      NaN  ...           NaN    +2 Vitesse
# 322       0,5      9,2      NaN      NaN  ...           NaN    +1 Attaque
# 321       NaN     25,0      NaN      NaN  ...           NaN    +2 Attaque
# 208      24,0    ???,?      NaN      NaN  ...           NaN           NaN
# 209       1,6     40,0      NaN      NaN  ...           NaN   +2 Att. Spé
# 181       0,9     28,0      NaN      NaN  ...           NaN           NaN
# 151       1,6     48,0      NaN      NaN  ...           NaN   +3 Att. Spé
# 144       1,0    120,0      NaN      NaN  ...           NaN         +2 PV
# 130       0,6      2,4      NaN      NaN  ...           NaN    +1 Attaque
# 53        1,2     39,8      NaN      NaN  ...           NaN           NaN
#
#       points_exp      exp_niv100     pv attaque attaque_speciale defense  \
# 1073     91 exp.  1 250 000 exp.   55.0    70.0             45.0    45.0
# 1051    134 exp.  1 059 860 exp.   55.0    95.0            115.0   115.0
# 803     181 exp.  1 059 860 exp.   90.0   100.0             60.0    60.0
# 666      66 exp.  1 059 860 exp.   53.0    51.0             53.0    53.0
# 665     143 exp.  1 059 860 exp.   64.0    66.0             68.0    68.0
# 664     210 exp.  1 059 860 exp.   84.0    86.0             88.0    88.0
# 545      56 exp.  1 059 860 exp.   55.0    75.0             85.0    85.0
# 523     214 exp.  1 059 860 exp.   60.0   100.0             89.0    89.0
# 517     161 exp.  1 000 000 exp.    NaN    92.0             65.0    65.0
# 452     234 exp.  1 059 860 exp.   60.0    55.0             90.0    90.0
# 420     261 exp.  1 250 000 exp.   79.0   115.0             70.0    70.0
# 419     261 exp.  1 250 000 exp.   79.0   115.0             70.0    70.0
# 416     270 exp.  1 250 000 exp.   89.0   125.0             90.0    90.0
# 401     239 exp.  1 059 860 exp.   72.0    95.0             67.0    67.0
# 381     163 exp.  1 000 000 exp.   74.0    48.0             76.0    76.0
# 322      56 exp.  1 000 000 exp.   45.0    65.0             40.0    40.0
# 321     170 exp.  1 000 000 exp.   75.0   115.0             65.0    65.0
# 208          NaN             NaN    NaN     NaN              NaN     NaN
# 209     176 exp.  1 059 860 exp.   75.0    98.0             70.0    70.0
# 181     166 exp.    800 000 exp.   60.0    65.0             55.0    55.0
# 151     116 exp.  1 250 000 exp.   74.0   115.0             70.0    70.0
# 144     171 exp.  1 000 000 exp.  110.0   100.0             75.0    75.0
# 130     146 exp.    600 000 exp.   82.0    96.0             51.0    51.0
# 53           NaN             NaN   80.0   120.0             84.0    84.0
#
#      defense_speciale  vitesse
# 1073             50.0     60.0
# 1051             45.0     35.0
# 803              60.0     80.0
# 666              56.0     40.0
# 665              76.0     50.0
# 664             101.0     60.0
# 545              25.0     15.0
# 523              69.0    112.0
# 517              55.0     98.0
# 452              90.0     80.0
# 420              80.0    111.0
# 419              80.0    111.0
# 416              80.0    101.0
# 401              71.0    122.0
# 381              81.0    104.0
# 322              40.0     60.0
# 321              65.0    112.0
# 208               NaN      NaN
# 209              70.0     75.0
# 181              95.0     95.0
# 151              80.0    106.0
# 144              80.0     65.0
# 130              51.0     92.0
# 53               96.0    110.0
#
# [24 rows x 25 columns]

# %%
conn = sqlite3.connect('../../../B___Data/pkmn.db')

# %%
test_response = ['Pokémon', 'type', 'Plante', 'Poison', 'première génération', 'Pokémon de départ', 'région', 'Kanto', 'bulbe', 'capacité', 'Vampigraine', 'Fouet Lianes', 'niveau', 'Herbizarre', 'Florizarre', 'sixième génération', 'méga-évoluer', 'Méga-Florizarre', 'Florizarrite', 'distribué de manière événementielle', 'Sacha', 'Samouraï', 'dessin animé', 'épisode 10', 'épisode 838', 'Arc Rouge, Bleu et Vert', 'chapitre 2', 'Tome 1', 'Rouge', 'chapitre 3', 'chapitre 4', 'chapitre 5', 'chapitre 6', 'chapitre 8', 'chapitre 9', 'chapitre 12', 'chapitre 13', 'Bleu', 'chapitre 15', 'Groundbreakers']

# %%
talents = ['Engrais', 'Chlorophylle', 'talent caché']

# %%
if len(talents) > 1 and 'talent caché' not in talents:
    talent_1 = talents[1]
elif len(talents) > 1 and 'talent caché' in talents:
    talent_cache = talents[-2]

# %%
if len(talents) == 1:
    talent_1 =talents[0]
elif len(talents) == 2 and 'talent caché' not in talents:
    talent_1 = talents[0]
    talent_2 = talents[1]
elif len(talents) == 2 and 'talent caché' in talents:
    talent_1 = talents[0]
    talent_cache = talents[-2]
elif len(talents) == 3:
    talent_1 = talents[0]
    talent_2 = talents[1]
    talent_cache = talents[-2]

# %%
print(talent_1, talent_2, talent_cache)
# Out:
# Engrais Chlorophylle Chlorophylle

# %%
text = R'12.5\xa0% femelle\u202f; 87.5\xa0% mâle'
clean_text = text.replace('\xa0', ' ').replace('\u202f', '')
print(clean_text)
# Out:
# 12.5\xa0% femelle\u202f; 87.5\xa0% mâle

# %%
pv, attaque, defense, attaque_speciale, defense_speciale, vitesse = None, None, None, None, None, None

# %%
liste = ['a', '1.5', 'b']

num = [x for x in liste if x[0].isdigit()][0]
num
# Out:
# '1.5'
