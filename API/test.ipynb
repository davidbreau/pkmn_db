# %%
import sys
sys.path.append('..')

# %%
from B___Data.pokemon import Pokemon
from B___Data.database import Database
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from B___Data.pokemon import Pokemon
#       2 from B___Data.database import Database
#
# File ~/Projets/pkmn_db/API/../B___Data/pokemon.py:3
#       1 import sqlite3, requests, os, sys, pygame
#       2 sys.path.append('..')
# ----> 3 from database import Database
#       4 from B___Data.connectors import Test_Database as Pkmn_Database
#       5 from typing import List; from io import BytesIO; from PIL import Image; from IPython.display import display
#
# ModuleNotFoundError: No module named 'database'

# %%
db = Database('../B___Data/pkmn.db')

# %%
pikachu = Pokemon(db'pikachu')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pikachu = Pokemon('pikachu')
#
# File ~/Projets/pkmn_db/API/../B___Data/pokemon.py:20, in __init__(self, nom_pkmn)
#      13 """
#      14 Initialize a Pokémon object and load its data from the database.
#      15
#      16 Args:
#      17     nom_pkmn (str): The name of the Pokémon, serving as a unique identifier.
#      18 """
#      19 self.nom_pkmn = nom_pkmn
# ---> 20 self.db = Pkmn_Database()
#      21 self._load_data()
#
# File ~/Projets/pkmn_db/API/../B___Data/pokemon.py:27, in _load_data(self)
#      26 def _load_data(self):
# ---> 27     """Load the Pokémon's data from the database and set attributes."""
#      28     connection = self.db.connect()
#      29     try:
#
# OperationalError: no such table: Pokemons
